# %% [markdown]
# # Working With Data - Continuous Assessment 1 - Class Group: TU059 / TU060

# %% [markdown]
# ## Ciaran Finnegan - Student No. d21124026

# %% [markdown]
# ### November 2021

# %% [markdown]
# ### What insights can various global socioecononmic and political datasets provide us in terms of explaining what makes a nation 'happy?

# %% [markdown]
# #### This project takes the World Happiness Report from Kaggle as the core dataset.
#
# A number of seperate global socioeconomic and political dataset are combined with this 'happiness' dataset to look for deeper insight of what actually may contribute to making a given country a 'happy' place.

# %% [markdown]
# ##

# %% [markdown]
# #### The CA follows a three-part structure.
#
# Works begins with initial data loads, and additional tasks to create our combined dataset of 'happiness' attributes for individuals countries.
#
# Exploration of the individual and merged datasets takes place to provide an overview of data strcuture and content.
#
# The project ends with a deeper dive into whether we can isolate more easily understood factors that impact on whther a country can be deemed 'happy' or not.

# %% [markdown]
# ###

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Seaborn" data-toc-modified-id="Seaborn-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Seaborn</a></span><ul class="toc-item"><li><span><a href="#Notebook-Modes" data-toc-modified-id="Notebook-Modes-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Notebook Modes</a></span></li><li><span><a href="#Dataset-Distribution" data-toc-modified-id="Dataset-Distribution-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Dataset Distribution</a></span></li><li><span><a href="#Categorical-Data" data-toc-modified-id="Categorical-Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Categorical Data</a></span></li><li><span><a href="#Time-Series-Data" data-toc-modified-id="Time-Series-Data-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Time-Series Data</a></span></li></ul></li><li><span><a href="#Pandas-Plotting" data-toc-modified-id="Pandas-Plotting-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Pandas Plotting</a></span></li><li><span><a href="#Plotly" data-toc-modified-id="Plotly-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Plotly</a></span><ul class="toc-item"><li><span><a href="#Transfer-Matplotlib-Figure-to-Plotly" data-toc-modified-id="Transfer-Matplotlib-Figure-to-Plotly-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Transfer Matplotlib Figure to Plotly</a></span></li></ul></li><li><span><a href="#Animation" data-toc-modified-id="Animation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Animation</a></span></li><li><span><a href="#Jupyter-Magic" data-toc-modified-id="Jupyter-Magic-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Jupyter Magic</a></span></li></ul></div>

# %% [markdown]
# # Part 1
#
# ## Import the piece/s of data and perform any cleaning and merging to produce a final dataframe.

# %% [markdown]
# Note: It is assumed that the matplotlib library has been installed on the user's machine before it is available for import.
#
# ```bash
# > pip install matplotlib
# ```

# %%
# Load libraries...
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Set up some additional libraries for graphical presentations

# %% [markdown]
# #### Seaborn Library

# %%
# import and set Seaborn style
# notice how this will update Matplotlib style too
import seaborn as sns
sns.set(style="darkgrid")
sns.set_context("talk", font_scale=1)

# %% [markdown]
# ###

# %% [markdown]
# Start with a 2015 Kaggle File that contains a happiness score (range 1 - 10) for 155 countries around the world.

# %%
# Read file, located in same directory as the notebook, for World Happiness Index data
df_WorldHappinessIndex = pd.read_csv('World_Happiness_Index_In_2015.csv')

# %%
# Display basic file data for the initial Kaggle 'Gloabl Happiness' datatset
df_WorldHappinessIndex
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %% [markdown]
# ####

# %% [markdown]
# To begin the process of building an augmented database on global nations 'happiness', the new dataset to load contains a comparison of GDP Per Capita and a Political Stability Index for individual countries over approximately the last 20 years.
#
# The source of the dataset is the Our World in Data website - https://ourworldindata.org/
#
# Our Kaggle dataset is only concerned with the year 2015 so we will be manipulating this GDP/Stability file to focus on just those entries.

# %%
# Read file, located in same directory as this notebook, for GDP/Political Stability data
df_GDPStateFragility = pd.read_csv('gdp-per-capita-vs-state-fragility.csv')

# %%
# Display basic dataframe information for GDP/Political Stability data
#df_GDPStateFragility

# %% [markdown]
# ####

# %% [markdown]
# The next file to load is the 'Human Freedom Index' - https://www.openintro.org/data/index.php?data=hfi
#
# This is a dataset sourced from the OpenIntro portal. Using the website's own description..."The Human Freedom Index is a report that attempts to summarize the idea of "freedom" through a bunch of different variables for many countries around the globe."

# %%
# Read file, located in same directory as this notebook, for Human Freedom Index data
df_HumanFreedomIndex = pd.read_csv('humanfreedomind.csv')

# %%
# Display basic dataframe information for Human Freedom Index data
df_HumanFreedomIndex.describe()
# Out:
#               year  pf_rol_procedural  pf_rol_civil  pf_rol_criminal  \
# count  1458.000000         880.000000    880.000000       880.000000
# mean   2012.000000           5.589355      5.474770         5.044070
# std       2.582875           2.080957      1.428494         1.724886
# min    2008.000000           0.000000      0.000000         0.000000
# 25%    2010.000000           4.133333      4.549550         3.789724
# 50%    2012.000000           5.300000      5.300000         4.575189
# 75%    2014.000000           7.389499      6.410975         6.400000
# max    2016.000000           9.700000      8.773533         8.719848
#
#             pf_rol  pf_ss_homicide  pf_ss_disappearances_disap  \
# count  1378.000000     1378.000000                 1369.000000
# mean      5.309641        7.412980                    8.341855
# std       1.529310        2.832947                    3.225902
# min       0.000000        0.000000                    0.000000
# 25%       4.131746        6.386978                   10.000000
# 50%       4.910797        8.638278                   10.000000
# 75%       6.513178        9.454402                   10.000000
# max       8.723094        9.926568                   10.000000
#
#        pf_ss_disappearances_violent  pf_ss_disappearances_organized  \
# count                   1378.000000                     1279.000000
# mean                       9.519458                        6.772869
# std                        1.744673                        2.768983
# min                        0.000000                        0.000000
# 25%                       10.000000                        5.000000
# 50%                       10.000000                        7.500000
# 75%                       10.000000                       10.000000
# max                       10.000000                       10.000000
#
#        pf_ss_disappearances_fatalities  ...  ef_regulation_business_bribes  \
# count                      1378.000000  ...                    1283.000000
# mean                          9.584972  ...                       4.886192
# std                           1.559826  ...                       1.889168
# min                           0.000000  ...                       0.000000
# 25%                           9.942607  ...                       3.433786
# 50%                          10.000000  ...                       4.418371
# 75%                          10.000000  ...                       6.227978
# max                          10.000000  ...                       9.623811
#
#        ef_regulation_business_licensing  ef_regulation_business_compliance  \
# count                       1357.000000                        1368.000000
# mean                           7.698494                           6.981858
# std                            1.728507                           1.979200
# min                            0.000000                           0.000000
# 25%                            6.874687                           6.368178
# 50%                            8.074161                           7.466692
# 75%                            8.991882                           8.209310
# max                            9.999638                           9.865488
#
#        ef_regulation_business  ef_regulation     ef_score      ef_rank  \
# count             1374.000000    1378.000000  1378.000000  1378.000000
# mean                 6.317668       7.019782     6.785610    76.973149
# std                  1.230988       1.027625     0.883601    44.540142
# min                  2.009841       2.483540     2.880000     1.000000
# 25%                  5.591851       6.429498     6.250000    38.000000
# 50%                  6.265234       7.082075     6.900000    77.000000
# 75%                  7.139718       7.720955     7.410000   115.000000
# max                  9.272600       9.439828     9.190000   162.000000
#
#           hf_score      hf_rank  hf_quartile
# count  1378.000000  1378.000000  1378.000000
# mean      6.993444    77.007983     2.490566
# std       1.025811    44.506549     1.119698
# min       3.765827     1.000000     1.000000
# 25%       6.336685    39.000000     1.000000
# 50%       6.923840    76.000000     2.000000
# 75%       7.894660   115.000000     3.000000
# max       9.126313   162.000000     4.000000
#
# [8 rows x 120 columns]

# %%
df_HumanFreedomIndex.head(7)
# Out:
#    year ISO_code  countries                         region  pf_rol_procedural  \
# 0  2016      ALB    Albania                 Eastern Europe           6.661503
# 1  2016      DZA    Algeria     Middle East & North Africa                NaN
# 2  2016      AGO     Angola             Sub-Saharan Africa                NaN
# 3  2016      ARG  Argentina  Latin America & the Caribbean           7.098483
# 4  2016      ARM    Armenia        Caucasus & Central Asia                NaN
# 5  2016      AUS  Australia                        Oceania           8.439110
# 6  2016      AUT    Austria                 Western Europe           8.969832
#
#    pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# 0      4.547244         4.666508  5.291752        8.920429
# 1           NaN              NaN  3.819566        9.456254
# 2           NaN              NaN  3.451814        8.060260
# 3      5.791960         4.343930  5.744791        7.622974
# 4           NaN              NaN  5.003205        8.808750
# 5      7.525648         7.364078  7.776279        9.623538
# 6      7.872188         7.673227  8.171749        9.737912
#
#    pf_ss_disappearances_disap  ...  ef_regulation_business_bribes  \
# 0                        10.0  ...                       4.050196
# 1                        10.0  ...                       3.765515
# 2                         5.0  ...                       1.945540
# 3                        10.0  ...                       3.260044
# 4                        10.0  ...                       4.575152
# 5                        10.0  ...                       7.238900
# 6                        10.0  ...                       6.418890
#
#    ef_regulation_business_licensing  ef_regulation_business_compliance  \
# 0                          7.324582                           7.074366
# 1                          8.523503                           7.029528
# 2                          8.096776                           6.782923
# 3                          5.253411                           6.508295
# 4                          9.319612                           6.491481
# 5                          8.944387                           8.823021
# 6                          7.296116                           8.531578
#
#    ef_regulation_business  ef_regulation  ef_score  ef_rank  hf_score  \
# 0                6.705863       6.906901      7.54     34.0  7.568140
# 1                5.676956       5.268992      4.99    159.0  5.135886
# 2                4.930271       5.518500      5.17    155.0  5.640662
# 3                5.535831       5.369019      4.84    160.0  6.469848
# 4                6.797530       7.378069      7.57     29.0  7.241402
# 5                8.121631       8.465526      7.98     10.0  8.582219
# 6                7.419870       7.371334      7.58     27.0  8.413474
#
#    hf_rank  hf_quartile
# 0     48.0          2.0
# 1    155.0          4.0
# 2    142.0          4.0
# 3    107.0          3.0
# 4     57.0          2.0
# 5      4.0          1.0
# 6     16.0          1.0
#
# [7 rows x 123 columns]

# %% [markdown]
# The Human Freedom Index contains variables which we will correlate later against the Happiness Index, but it also contains the useful country attributes for ISO code and World Region that will be useful in later analysis.

# %% [markdown]
# ####

# %% [markdown]
# ####

# %% [markdown]
# The next dataset to load is the 'CIA Factbook Details on Countries'.
#
# This is a collection of country-level statistics from the US Central Intelligence Agency (CIA). It contains a series of attributes that we will compare against the 'happiness index' to determine if we can find any meaningful and interesting correlations.

# %%
# Read file, located in same directory as this notebook, for CIA Factbook data
df_CIAFactbook = pd.read_csv('cia_factbook.csv')

# %%
# Display basic file data for the initial Kaggle 'Gloabl Happiness' datatset
df_CIAFactbook
# Out:
#               country        area  birth_rate  death_rate  \
# 0              Russia  17098242.0       11.87       13.83
# 1              Canada   9984670.0       10.29        8.31
# 2       United States   9826675.0       13.42        8.15
# 3               China   9596960.0       12.17        7.44
# 4              Brazil   8514877.0       14.72        6.54
# ..                ...         ...         ...         ...
# 254     Bouvet Island        49.0         NaN         NaN
# 255     Palmyra Atoll        12.0         NaN         NaN
# 256          Akrotiri       123.0         NaN         NaN
# 257    European Union         NaN         NaN         NaN
# 258  Saint Barthelemy         NaN         NaN         NaN
#
#      infant_mortality_rate  internet_users  life_exp_at_birth  \
# 0                     7.08      40853000.0              70.16
# 1                     4.71      26960000.0              81.67
# 2                     6.17     245000000.0              79.56
# 3                    14.79     389000000.0              75.15
# 4                    19.21      75982000.0              73.28
# ..                     ...             ...                ...
# 254                    NaN             NaN                NaN
# 255                    NaN             NaN                NaN
# 256                    NaN             NaN                NaN
# 257                   4.33             NaN              80.02
# 258                    NaN             NaN                NaN
#
#      maternal_mortality_rate  net_migration_rate    population  \
# 0                       34.0                1.69  1.424703e+08
# 1                       12.0                5.66  3.483484e+07
# 2                       21.0                2.45  3.188921e+08
# 3                       37.0               -0.32  1.355693e+09
# 4                       56.0               -0.15  2.026568e+08
# ..                       ...                 ...           ...
# 254                      NaN                 NaN           NaN
# 255                      NaN                 NaN           NaN
# 256                      NaN                 NaN           NaN
# 257                      NaN                 NaN  5.114348e+08
# 258                      NaN                 NaN  7.267000e+03
#
#      population_growth_rate
# 0                     -0.03
# 1                      0.76
# 2                      0.77
# 3                      0.44
# 4                      0.80
# ..                      ...
# 254                     NaN
# 255                     NaN
# 256                     NaN
# 257                     NaN
# 258                     NaN
#
# [259 rows x 11 columns]

# %% [markdown]
# #

# %% [markdown]
# Part 2 of this report will delve into all the datasets in more detail but for now let's generate some basic graphs of the data loaded to confirm some basic details.

# %% [markdown]
# First: A quick look at the top and bottom of the Kaggle dataset 'happiness' index..

# %%
# Vertical Bar Chart of top nations in happiness index
# The 'Top 20' cut off allows 'Ireland' to be included in graph
top_20 = df_WorldHappinessIndex[df_WorldHappinessIndex["Happiness Rank"] < 20] 

# Plot horizontal bar chart with Matplotlib
top_20.sort_values("Happiness Score",ascending=True).plot.barh(x="Country", y="Happiness Score")
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
# Vertical Bar Chart of bottom nations in happiness index
# The bottom 10 are sufficient for this graph
bottom_10 = df_WorldHappinessIndex[df_WorldHappinessIndex["Happiness Rank"] > 145] 

# Plot horizontal bar chart with Matplotlib
bottom_10.sort_values("Happiness Score",ascending=True).plot.barh(x="Country", y="Happiness Score")
# Out:
# <AxesSubplot:ylabel='Country'>

# %% [markdown]
# ####

# %% [markdown]
# Second: A brief overview of the GDP/State Fragility data

# %%
# Some code here...

# %% [markdown]
# ####

# %% [markdown]
# Third: A quick look at the structure of the 'Human Freedom' index..

# %%
# Some code here..
# sns.pairplot(df_HumanFreedomIndex, hue='region')

# %% [markdown]
# ####

# %% [markdown]
# Fourth: A quick look at the structure of the 'CIA Country Factbook' index..

# %% [markdown]
# ####

# %% [markdown]
# ## Clean Up Datasets
# ### There are some missing data attributes and issus with some of the data content which need to be addressed before we can create a merged custom 'happiness' dataset with which to generate the interesting/insightful visualisations.

# %% [markdown]
# Kaggle Happiness: The assumption is the our initial dataset, which is the Kaggle happiness index, is clean and complete but some basic checks are performed here.

# %% [markdown]
# To improve the later vizualisations columns will be remaned in each dataframe to emhance understanding/presentation.

# %%
df_WorldHappinessIndex.rename(columns={'Economy (GDP per Capita)':'GDP per Capita',
                        'Health (Life Expectancy)':'Life Expectancy',             
                        'Trust (Government Corruption)':'Trust in Gov'},inplace=True)

# %%
# Checking for null values in Kaggle Happiness dataset
[print('Any Null Values in the Kaggle 2015 Happiness Dataframe?','\n' ,df_WorldHappinessIndex.isnull().any())]
# Out:
# Any Null Values in the Kaggle 2015 Happiness Dataframe?
#  Country              False
# Region               False
# Happiness Rank       False
# Happiness Score      False
# Standard Error       False
# GDP per Capita       False
# Family               False
# Life Expectancy      False
# Freedom              False
# Trust in Gov         False
# Generosity           False
# Dystopia Residual    False
# dtype: bool
# [None]

# %%
## Although it is an unlikely scenario - a quick check is run to see if any duplicate entires exist
[print('Numbers of duplicated rows in the Kaggle 2015 Happiness Dataframe?','\n' ,df_WorldHappinessIndex.duplicated().sum())]
# Out:
# Numbers of duplicated rows in the Kaggle 2015 Happiness Dataframe?
#  0
# [None]

# %% [markdown]
# The 2015 Kaggle dataset has no missing data and is ready for us to proceed.

# %% [markdown]
# ####

# %% [markdown]
# GDP/Political Fragility: Even a general visual inspection of the dataset overview in the earlier section of this report will show that there are data gaps in this dataset.

# %% [markdown]
# We only need the 2015 data so our first step is to filter out this information and then assess the data quality.

# %%
## Filter the dataset to extract only the 2015 data rows from the GDP/Political State Fragility data

# %%
df_GDPStateFragility_2015 = df_GDPStateFragility[df_GDPStateFragility['Year'] == 2015]

# %%
## Rename Columns - to improve data understanding
df_GDPStateFragility_2015.rename(columns={'Entity':'Country', 'Code':'ISO_Country_Cd', 
                        'GDP per capita, PPP (constant 2017 international $)':'GDP per capita', 
                        'Fragile States Index - ffp_fsi':'Political Fragility',
                        'Total population (Gapminder, HYDE & UN)':'Population'},inplace=True)

# %%
## check dataset structure again
df_GDPStateFragility_2015
# Out:
#                            Country ISO_Country_Cd  Year  GDP per capita  \
# 0                         Abkhazia       OWID_ABK  2015             NaN
# 14                     Afghanistan            AFG  2015     2068.265904
# 512                         Africa            NaN  2015             NaN
# 544    Africa Eastern and Southern            NaN  2015     3549.480563
# 575     Africa Western and Central            NaN  2015     4202.057923
# ...                            ...            ...   ...             ...
# 56598                   Yugoslavia       OWID_YGS  2015             NaN
# 56624                       Zambia            ZMB  2015     3443.553254
# 56858                     Zanzibar       OWID_ZAN  2015             NaN
# 56884                     Zimbabwe            ZWE  2015     3198.982129
# 57118                Åland Islands            ALA  2015             NaN
#
#        Political Fragility    Population Continent
# 0                      NaN           NaN      Asia
# 14                   107.9  3.441360e+07      Asia
# 512                    NaN  1.182439e+09       NaN
# 544                    NaN           NaN       NaN
# 575                    NaN           NaN       NaN
# ...                    ...           ...       ...
# 56598                  NaN           NaN    Europe
# 56624                 86.3  1.587937e+07    Africa
# 56858                  NaN           NaN    Africa
# 56884                100.5  1.381464e+07    Africa
# 57118                  NaN           NaN    Europe
#
# [340 rows x 7 columns]

# %% [markdown]
# We will be using a later dataset for 'Regional' global breakdowns, as our immediate concern is only for data rows with valid country codes. The rows with no ISO codes will be checked and dropped from this 2015 GDP/Political Fragility dataset.

# %%
## Filer out tthe 2015 GDP/Political Fragility dataframe to look at rows with missing ISO Country Codes

# %%
df_temp = df_GDPStateFragility_2015.loc[df_GDPStateFragility_2015["ISO_Country_Cd"].isnull()]

# %%
#df_temp

# %%
# Rows and Columns
df_temp.shape
# Out:
# (54, 7)

# %%
df_GDPStateFragility_2015 = df_GDPStateFragility_2015.loc[df_GDPStateFragility_2015["ISO_Country_Cd"].notnull()]

# %%
df_GDPStateFragility_2015
# Out:
#                      Country ISO_Country_Cd  Year  GDP per capita  \
# 0                   Abkhazia       OWID_ABK  2015             NaN
# 14               Afghanistan            AFG  2015     2068.265904
# 581    Akrotiri and Dhekelia       OWID_AKD  2015             NaN
# 607                  Albania            ALB  2015    11878.488093
# 866                  Algeria            DZA  2015    11696.965229
# ...                      ...            ...   ...             ...
# 56598             Yugoslavia       OWID_YGS  2015             NaN
# 56624                 Zambia            ZMB  2015     3443.553254
# 56858               Zanzibar       OWID_ZAN  2015             NaN
# 56884               Zimbabwe            ZWE  2015     3198.982129
# 57118          Åland Islands            ALA  2015             NaN
#
#        Political Fragility  Population Continent
# 0                      NaN         NaN      Asia
# 14                   107.9  34413603.0      Asia
# 581                    NaN         NaN      Asia
# 607                   61.2   2890524.0    Europe
# 866                   78.3  39728020.0    Africa
# ...                    ...         ...       ...
# 56598                  NaN         NaN    Europe
# 56624                 86.3  15879370.0    Africa
# 56858                  NaN         NaN    Africa
# 56884                100.5  13814642.0    Africa
# 57118                  NaN         NaN    Europe
#
# [286 rows x 7 columns]

# %%
## Check for Null GDP values - can these also be removed?

# %%
df_temp2 = df_GDPStateFragility_2015.loc[df_GDPStateFragility_2015["Political Fragility"].isnull()]

# %%
df_temp2
# Out:
#                        Country ISO_Country_Cd  Year  GDP per capita  \
# 0                     Abkhazia       OWID_ABK  2015             NaN
# 581      Akrotiri and Dhekelia       OWID_AKD  2015             NaN
# 1207            American Samoa            ASM  2015             NaN
# 1466                   Andorra            AND  2015             NaN
# 1846                  Anguilla            AIA  2015             NaN
# ...                        ...            ...   ...             ...
# 56596      Yemen Arab Republic       OWID_YAR  2015             NaN
# 56597  Yemen People's Republic       OWID_YPR  2015             NaN
# 56598               Yugoslavia       OWID_YGS  2015             NaN
# 56858                 Zanzibar       OWID_ZAN  2015             NaN
# 57118            Åland Islands            ALA  2015             NaN
#
#        Political Fragility  Population      Continent
# 0                      NaN         NaN           Asia
# 581                    NaN         NaN           Asia
# 1207                   NaN     55806.0        Oceania
# 1466                   NaN     77993.0         Europe
# 1846                   NaN     14279.0  North America
# ...                    ...         ...            ...
# 56596                  NaN         NaN           Asia
# 56597                  NaN         NaN           Asia
# 56598                  NaN         NaN         Europe
# 56858                  NaN         NaN         Africa
# 57118                  NaN         NaN         Europe
#
# [109 rows x 7 columns]

# %%
## Check for Null Political Fragility values - what is the impact of removing these?

# %%
df_GDPStateFragility_2015 = df_GDPStateFragility_2015.loc[df_GDPStateFragility_2015["Political Fragility"].notnull()]

# %%
df_GDPStateFragility_2015
# Out:
#                    Country ISO_Country_Cd  Year  GDP per capita  \
# 14             Afghanistan            AFG  2015     2068.265904
# 607                Albania            ALB  2015    11878.488093
# 866                Algeria            DZA  2015    11696.965229
# 1498                Angola            AGO  2015     8036.410898
# 1879   Antigua and Barbuda            ATG  2015    18594.261624
# ...                    ...            ...   ...             ...
# 55384            Venezuela            VEN  2015    16055.650000
# 55657              Vietnam            VNM  2015     6438.259854
# 56348                Yemen            YEM  2015      824.120000
# 56624               Zambia            ZMB  2015     3443.553254
# 56884             Zimbabwe            ZWE  2015     3198.982129
#
#        Political Fragility  Population      Continent
# 14                   107.9  34413603.0           Asia
# 607                   61.2   2890524.0         Europe
# 866                   78.3  39728020.0         Africa
# 1498                  90.5  27884380.0         Africa
# 1879                  56.2     93571.0  North America
# ...                    ...         ...            ...
# 55384                 81.6  30081827.0  South America
# 55657                 70.7  92677082.0           Asia
# 56348                111.5  26497881.0           Asia
# 56624                 86.3  15879370.0         Africa
# 56884                100.5  13814642.0         Africa
#
# [177 rows x 7 columns]

# %%
## Although it is an unlikely scenario - a quick check is run to see if any duplicate entires exist
[print('Numbers of duplicated rows in the State Fragility 2015 Dataframe?','\n' ,df_GDPStateFragility_2015.duplicated().sum())]
# Out:
# Numbers of duplicated rows in the State Fragility 2015 Dataframe?
#  0
# [None]

# %%
## Rename Columns to improve data descriptions

# %%
# There will be some gaps on Political Fragility to be filled in later...

# %%
#df_HumanFreedomIndex

# %%
# Only select the four data attributes entries that we need (for the year 2015) from Human Freedon Index dataframe
df_FreedonTemp1 = df_HumanFreedomIndex.loc[(df_HumanFreedomIndex['year'] == 2015), 
                                           ["year","ISO_code",
                                           "countries","hf_score","hf_rank"]]

# %%
## Rename Columns in temp 'Human Freedom' dataframe to allow joining/merging on ISO value for countries
df_FreedonTemp1.rename(columns={'ISO_code':'ISO_Country_Cd'},inplace=True)

# %%
# Checking for null values in Human Freedon Index dataframe
[print('Any Null Values in the Human Freedon Index dataframe?','\n' ,df_FreedonTemp1.isnull().any())]
# Out:
# Any Null Values in the Human Freedon Index dataframe?
#  year              False
# ISO_Country_Cd    False
# countries         False
# hf_score           True
# hf_rank            True
# dtype: bool
# [None]

# %%
# Pull out data rows into a temporary dataframe to examine records with null values in 'hf_score' and 'hf_rank'
df_FreedonTemp2a = df_HumanFreedomIndex.loc[(df_HumanFreedomIndex['year'] == 2015) 
                                           & df_HumanFreedomIndex["hf_rank"].isnull(), ["year","ISO_code",
                                           "countries","hf_score","hf_rank"]]

df_FreedonTemp2b = df_HumanFreedomIndex.loc[(df_HumanFreedomIndex['year'] == 2015) 
                                           & df_HumanFreedomIndex["hf_score"].isnull(), ["year","ISO_code",
                                           "countries","hf_score","hf_rank"]]

# %%
# Look at data rows with missing values for Human Freedom rankings for nations
df_FreedonTemp2a.sort_values("hf_rank")
# Out:
#      year ISO_code countries  hf_score  hf_rank
# 174  2015      BLR   Belarus       NaN      NaN
# 231  2015      IRQ      Iraq       NaN      NaN
# 298  2015      SDN     Sudan       NaN      NaN

# %%
# Look at data rows with missing values for Human Freedom scores for nations
df_FreedonTemp2b.sort_values("hf_score")
# Out:
#      year ISO_code countries  hf_score  hf_rank
# 174  2015      BLR   Belarus       NaN      NaN
# 231  2015      IRQ      Iraq       NaN      NaN
# 298  2015      SDN     Sudan       NaN      NaN

# %% [markdown]
# Both dataframe are identical so the missing data is just for three countries. For simplicity we sources this missing data manually from the 'Human Freedon' PDF report and built a dataframe manually to patch the data

# %%
#set up dataframe to update missing Human Freedom Index scores
# BLR hf_score = 3.65 hf_rank = 160
# IRQ hf_score = 3.34 hf_rank = 161
# SDN hf_score = 3.32 hf_rank = 162
df_Cntry_To_Update_HF = pd.DataFrame({'ISO_Country_Cd': ['BLR','IRQ','SDN'],
                   'hf_score': [3.65, 3.34, 3.32],
                   'hf_rank': [160, 161, 162]})

# %%
# Display new manually create dataset with missing 'Human Freedom' values
df_Cntry_To_Update_HF
# Out:
#   ISO_Country_Cd  hf_score  hf_rank
# 0            BLR      3.65      160
# 1            IRQ      3.34      161
# 2            SDN      3.32      162

# %%
# Write a python function to update a dataframe with attributes in another datafram
# We will use this function to provide a re-usable mechanism to patch missing data in the datasets we are loading
# from external sources

def update_country_dataset_wtih_new_dataframe(to_df, from_df):
    
    for i in range(len(from_df)):
    
        index = to_df.index
        condition = to_df[from_df.columns[0]] == from_df.iloc[i,0]
        cntry_index = index[condition]
        to_df.at[cntry_index, from_df.columns[1]] = from_df.iloc[i,1]
        to_df.at[cntry_index, from_df.columns[2]] = from_df.iloc[i,2]
        print("{}:Counter in Loop - Index in Temp = {} Country {}\n".format(i,cntry_index,from_df.iloc[i,0]))
    
    
    return "Here is the function"

# %%
# Call function to update main dataframe with new freedom scores
update_country_dataset_wtih_new_dataframe(df_FreedonTemp1, df_Cntry_To_Update_HF)
# Out:
# 0:Counter in Loop - Index in Temp = Int64Index([174], dtype='int64') Country BLR
#
# 1:Counter in Loop - Index in Temp = Int64Index([231], dtype='int64') Country IRQ
#
# 2:Counter in Loop - Index in Temp = Int64Index([298], dtype='int64') Country SDN
# 'Here is the function'

# %%
#loop through update values
#for i in range(len(df_Cntry_To_Update_HF)):
    
#    index = df_FreedonTemp1.index
#    condition = df_FreedonTemp1[df_Cntry_To_Update_HF.columns[0]] == df_Cntry_To_Update_HF.iloc[i,0]
#    cntry_index = index[condition]
#    df_FreedonTemp1.at[cntry_index, df_Cntry_To_Update_HF.columns[1]] = df_Cntry_To_Update_HF.iloc[i,1]
#    df_FreedonTemp1.at[cntry_index, df_Cntry_To_Update_HF.columns[2]] = df_Cntry_To_Update_HF.iloc[i,2]
#    print("{}:Counter in Loop - Index in Temp = {} Country {}\n".format(i,cntry_index,df_Cntry_To_Update_HF.iloc[i,0]))

# %%
df_FreedonTemp1.sort_values("hf_rank",ascending=False)
# Out:
#      year ISO_Country_Cd    countries  hf_score  hf_rank
# 298  2015            SDN        Sudan  3.320000    162.0
# 231  2015            IRQ         Iraq  3.340000    161.0
# 174  2015            BLR      Belarus  3.650000    160.0
# 303  2015            SYR        Syria  3.910826    159.0
# 321  2015            YEM  Yemen, Rep.  4.203442    158.0
# ..    ...            ...          ...       ...      ...
# 167  2015            AUS    Australia  8.607373      5.0
# 232  2015            IRL      Ireland  8.645525      4.0
# 302  2015            CHE  Switzerland  8.814458      3.0
# 225  2015            HKG    Hong Kong  8.857581      2.0
# 269  2015            NZL  New Zealand  8.876890      1.0
#
# [162 rows x 5 columns]

# %%
# Checking for null values in Human Freedon Index dataframe
[print('Any Null Values in the Human Freedon Index dataframe?','\n' ,df_FreedonTemp1.isnull().any())]
# Out:
# Any Null Values in the Human Freedon Index dataframe?
#  year              False
# ISO_Country_Cd    False
# countries         False
# hf_score          False
# hf_rank           False
# dtype: bool
# [None]

# %% [markdown]
# All missing 'human freedom' data is now in place.

# %%
## Although it is an unlikely scenario - a quick check is run to see if any duplicate entires exist
[print('Numbers of duplicated rows in the Human Freedon Index 2015 dataframe?','\n' ,df_FreedonTemp1.duplicated().sum())]
# Out:
# Numbers of duplicated rows in the Human Freedon Index 2015 dataframe?
#  0
# [None]

# %% [markdown]
# #### We will use this temporary 'human freedom' dataframe to augment our primary 'Happiness' dataframe in the section below.

# %% [markdown]
# ####

# %% [markdown]
# ####

# %% [markdown]
# ## Merge Datasets
# Using common country identifiers across the datasets, we combine the data into a single new dataframe for further visualisation.

# %% [markdown]
# #

# %% [markdown]
# #### Join the Kaggle 2016 Happiness dataframe to the State Fragility dataframe

# %%
# Dataframe are slightly difference sizes - Check for differences

# %%
# Create Basis of merged dataframe - start with Kaggle Happiness 2015
#df_HappinessFactors_temp = df_WorldHappinessIndex.sort_values("Country",ascending=True).iloc[:, [0, 1, 2, 3, 9]]
df_HappinessFactors_temp = df_WorldHappinessIndex.iloc[:, [0, 1, 2, 3, 9]]
df_HappinessFactors_temp
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Trust in Gov
# 0              7.587       0.41978
# 1              7.561       0.14145
# 2              7.527       0.48357
# 3              7.522       0.36503
# 4              7.427       0.32957
# ..               ...           ...
# 153            3.465       0.55191
# 154            3.340       0.08010
# 155            3.006       0.18906
# 156            2.905       0.10062
# 157            2.839       0.10731
#
# [158 rows x 5 columns]

# %%
# Next pick fields we want from State Fragility
#df_FragilityFactors_temp = df_GDPStateFragility_2015.sort_values("Country",ascending=True).iloc[:, [0, 1, 3, 4, 6]]
df_FragilityFactors_temp = df_GDPStateFragility_2015.iloc[:, [0, 1, 3, 4, 6]]
df_FragilityFactors_temp
# Out:
#                    Country ISO_Country_Cd  GDP per capita  \
# 14             Afghanistan            AFG     2068.265904
# 607                Albania            ALB    11878.488093
# 866                Algeria            DZA    11696.965229
# 1498                Angola            AGO     8036.410898
# 1879   Antigua and Barbuda            ATG    18594.261624
# ...                    ...            ...             ...
# 55384            Venezuela            VEN    16055.650000
# 55657              Vietnam            VNM     6438.259854
# 56348                Yemen            YEM      824.120000
# 56624               Zambia            ZMB     3443.553254
# 56884             Zimbabwe            ZWE     3198.982129
#
#        Political Fragility      Continent
# 14                   107.9           Asia
# 607                   61.2         Europe
# 866                   78.3         Africa
# 1498                  90.5         Africa
# 1879                  56.2  North America
# ...                    ...            ...
# 55384                 81.6  South America
# 55657                 70.7           Asia
# 56348                111.5           Asia
# 56624                 86.3         Africa
# 56884                100.5         Africa
#
# [177 rows x 5 columns]

# %%
#Trim text values for string matching on country names
df_HappinessFactors_temp['Country'] = df_HappinessFactors_temp['Country'].str.strip()
df_FragilityFactors_temp['Country'] = df_FragilityFactors_temp['Country'].str.strip()

# %%
# Build our primary dataset on Happiness Factors per nation
# Join on the 2015 Kaggle table and only select country data from the Fragility dataframe for which we have a happiness score
# in the Kaggle dataframe
df_HappinessFactorsbyNation = pd.merge(df_HappinessFactors_temp, df_FragilityFactors_temp, how="left", on=["Country"])

# %% [markdown]
# #### The merging of these data frames provides our new primary 'happiness' dataframe with the following attributes;
#
# ```bash
#  -  A More meaningful GDP data measure
#  -  A 'Political Fragility' index. The higher the value, the less politically stable the county
# ```
#
# The following data attribute will allow us to merge the additional datasets in this assignment;
#
# ```bash
#  -  ISO Coutry Code
# ```

# %%
## Checking for null values in new Happiness Factors dataframe
[print('Any Null Values in the new Happiness Factors dataframe?','\n' ,df_HappinessFactorsbyNation.isnull().any())]
# Out:
# Any Null Values in the new Happiness Factors dataframe?
#  Country                False
# Region                 False
# Happiness Rank         False
# Happiness Score        False
# Trust in Gov           False
# ISO_Country_Cd          True
# GDP per capita          True
# Political Fragility     True
# Continent               True
# dtype: bool
# [None]

# %%
# Produce a table of countries missing an ISO Country Code
df_tempISO = df_HappinessFactorsbyNation[df_HappinessFactorsbyNation["ISO_Country_Cd"].isnull()]
df_tempISO
# Out:
#                      Country                           Region  Happiness Rank  \
# 30            Czech Republic       Central and Eastern Europe              31
# 65              North Cyprus                   Western Europe              66
# 68                    Kosovo       Central and Eastern Europe              69
# 71                 Hong Kong                     Eastern Asia              72
# 90         Somaliland region               Sub-Saharan Africa              91
# 92                 Macedonia       Central and Eastern Europe              93
# 100                Swaziland               Sub-Saharan Africa             101
# 107  Palestinian Territories  Middle East and Northern Africa             108
# 119         Congo (Kinshasa)               Sub-Saharan Africa             120
# 138      Congo (Brazzaville)               Sub-Saharan Africa             139
# 150              Ivory Coast               Sub-Saharan Africa             151
#
#      Happiness Score  Trust in Gov ISO_Country_Cd  GDP per capita  \
# 30             6.505       0.02652            NaN             NaN
# 65             5.695       0.14280            NaN             NaN
# 68             5.589       0.04741            NaN             NaN
# 71             5.474       0.37124            NaN             NaN
# 90             5.057       0.39928            NaN             NaN
# 92             5.007       0.05327            NaN             NaN
# 100            4.867       0.03060            NaN             NaN
# 107            4.715       0.12905            NaN             NaN
# 119            4.517       0.07625            NaN             NaN
# 138            3.989       0.11686            NaN             NaN
# 150            3.655       0.17922            NaN             NaN
#
#      Political Fragility Continent
# 30                   NaN       NaN
# 65                   NaN       NaN
# 68                   NaN       NaN
# 71                   NaN       NaN
# 90                   NaN       NaN
# 92                   NaN       NaN
# 100                  NaN       NaN
# 107                  NaN       NaN
# 119                  NaN       NaN
# 138                  NaN       NaN
# 150                  NaN       NaN

# %% [markdown]
# Gaps in the data have been introduced by country data that is missing a 'Political Fragility' index, which also results in missing ISO Country Codes for some nations.
#
# Looking at the nation list above, it was felt acceptable that these nations or political regions could be removed from our analysis.
#
# The 'Czech Republic' is completely missing from the State Fragility dataset.

# %%
# Remove rows with no ISO Country Code
df_HappinessFactorsbyNation = df_HappinessFactorsbyNation.loc[df_HappinessFactorsbyNation["ISO_Country_Cd"].notnull()]

# %% [markdown]
# #### What about the rows in the 'State Fragility' dataframe for which there is no 'happiness' index?

# %% [markdown]
# There are rows row individual nations in the State Fragility dataframe that in the original Kaggle Happiness dataset.
#
# Below is a quick examination of the nation entries being excluded from our new primary Happiness dataframe.

# %%
# Check the countries in the State Fragile dataframe that do not exist in the Kaggle Happiness dataframe
df_NoHappinessIndexFragileStates = pd.merge(df_FragilityFactors_temp, df_HappinessFactors_temp,  how="left", on=["Country"], 
                 indicator=True)

# The 'indicator' flag allows us to isolate the nations that only exist in the State Fragility dataframe - those rows 
# are marked as 'left_only'
df_NoHappinessIndexFragileStates = df_NoHappinessIndexFragileStates[df_NoHappinessIndexFragileStates["_merge"] == 'left_only']

# Display country list 'missing' from the original Kaggle dataframe
df_NoHappinessIndexFragileStates
# Out:
#                    Country ISO_Country_Cd  GDP per capita  \
# 4      Antigua and Barbuda            ATG    18594.261624
# 10                 Bahamas            BHS    35400.649466
# 13                Barbados            BRB    15382.765689
# 16                  Belize            BLZ     7358.582292
# 23                  Brunei            BRN    63147.483490
# 30              Cape Verde            CPV     6266.881779
# 37                   Congo            COG     5227.934277
# 39           Cote d'Ivoire            CIV     4417.150215
# 41                    Cuba            CUB             NaN
# 43                 Czechia            CZE    36168.418555
# 50       Equatorial Guinea            GNQ    28313.433159
# 51                 Eritrea            ERI             NaN
# 53                Eswatini            SWZ     8304.658458
# 55                    Fiji            FJI    12569.143113
# 59                  Gambia            GMB     2058.658146
# 64                 Grenada            GRD    15142.062570
# 67           Guinea-Bissau            GNB     1800.063382
# 68                  Guyana            GUY    11261.813707
# 98                Maldives            MDV    17284.647894
# 104   Micronesia (country)            FSM     3448.303692
# 111                Namibia            NAM    10662.829930
# 118        North Macedonia            MKD    15072.947542
# 123       Papua New Guinea            PNG     4083.752437
# 133                  Samoa            WSM     5992.439321
# 134  Sao Tome and Principe            STP     3794.358595
# 138             Seychelles            SYC    25500.486559
# 143        Solomon Islands            SLB     2518.647478
# 144                Somalia            SOM      879.276532
# 147            South Sudan            SSD             NaN
# 159                  Timor            TLS     3297.889163
#
#      Political Fragility      Continent Region  Happiness Rank  \
# 4                   56.2  North America    NaN             NaN
# 10                  51.6  North America    NaN             NaN
# 13                  49.0  North America    NaN             NaN
# 16                  66.0  North America    NaN             NaN
# 23                  62.0           Asia    NaN             NaN
# 30                  71.5         Africa    NaN             NaN
# 37                  92.2         Africa    NaN             NaN
# 39                  97.9         Africa    NaN             NaN
# 41                  66.3  North America    NaN             NaN
# 43                  40.8         Europe    NaN             NaN
# 50                  85.2         Africa    NaN             NaN
# 51                  98.6         Africa    NaN             NaN
# 53                  87.6         Africa    NaN             NaN
# 55                  76.2        Oceania    NaN             NaN
# 59                  86.8         Africa    NaN             NaN
# 64                  63.0  North America    NaN             NaN
# 67                  99.8         Africa    NaN             NaN
# 68                  70.9  South America    NaN             NaN
# 98                  74.0           Asia    NaN             NaN
# 104                 77.1        Oceania    NaN             NaN
# 111                 71.1         Africa    NaN             NaN
# 118                 67.0         Europe    NaN             NaN
# 123                 86.2        Oceania    NaN             NaN
# 133                 67.6        Oceania    NaN             NaN
# 134                 72.9         Africa    NaN             NaN
# 138                 60.2         Africa    NaN             NaN
# 143                 85.3        Oceania    NaN             NaN
# 144                114.0         Africa    NaN             NaN
# 147                113.8         Africa    NaN             NaN
# 159                 90.8           Asia    NaN             NaN
#
#      Happiness Score  Trust in Gov     _merge
# 4                NaN           NaN  left_only
# 10               NaN           NaN  left_only
# 13               NaN           NaN  left_only
# 16               NaN           NaN  left_only
# 23               NaN           NaN  left_only
# 30               NaN           NaN  left_only
# 37               NaN           NaN  left_only
# 39               NaN           NaN  left_only
# 41               NaN           NaN  left_only
# 43               NaN           NaN  left_only
# 50               NaN           NaN  left_only
# 51               NaN           NaN  left_only
# 53               NaN           NaN  left_only
# 55               NaN           NaN  left_only
# 59               NaN           NaN  left_only
# 64               NaN           NaN  left_only
# 67               NaN           NaN  left_only
# 68               NaN           NaN  left_only
# 98               NaN           NaN  left_only
# 104              NaN           NaN  left_only
# 111              NaN           NaN  left_only
# 118              NaN           NaN  left_only
# 123              NaN           NaN  left_only
# 133              NaN           NaN  left_only
# 134              NaN           NaN  left_only
# 138              NaN           NaN  left_only
# 143              NaN           NaN  left_only
# 144              NaN           NaN  left_only
# 147              NaN           NaN  left_only
# 159              NaN           NaN  left_only

# %% [markdown]
# Many of these entries are small island nations, which presumably were not included in the analysis that led to the creation
# of the origina; Kaggle dataset.
#
# It is assumed, for the purposes of this assignment, that not including these countries in our visualisations will be acceptable. It will still be possible to determine useful data from our refined 'happiness' dataframe.

# %% [markdown]
# #

# %% [markdown]
# #### Join our new Happiness dataframe to the temporary dataframe we created to store 'human freedom' attributes

# %% [markdown]
# #### The merging of these data frames provides our new primary 'happiness' dataframe with the following attributes;
#
# ```bash
#  -  A 'Human Freedom' ranking per nation
#  -  A 'Freedom' score for each nation
# ```

# %%
df_HappinessFactorsbyNation.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  Trust in Gov  \
# 0  Switzerland  Western Europe               1            7.587       0.41978
# 1      Iceland  Western Europe               2            7.561       0.14145
# 2      Denmark  Western Europe               3            7.527       0.48357
# 3       Norway  Western Europe               4            7.522       0.36503
# 4       Canada   North America               5            7.427       0.32957
#
#   ISO_Country_Cd  GDP per capita  Political Fragility      Continent  \
# 0            CHE    68025.920038                 21.8         Europe
# 1            ISL    52142.932807                 22.8         Europe
# 2            DNK    52892.646029                 21.5         Europe
# 3            NOR    62987.535863                 21.2         Europe
# 4            CAN    47522.140667                 23.8  North America
#
#    hf_score  hf_rank
# 0  8.814458      3.0
# 1  8.199764     27.0
# 2  8.543023      8.0
# 3  8.519496     10.0
# 4  8.520056     10.0

# %%
df_HpyFactor_Temp = df_HappinessFactorsbyNation

# %%
df_FreedonTemp1.head()
# Out:
#      year ISO_Country_Cd  countries  hf_score  hf_rank
# 162  2015            ALB    Albania  7.558539     49.0
# 163  2015            DZA    Algeria  5.082655    152.0
# 164  2015            AGO     Angola  5.786479    137.0
# 165  2015            ARG  Argentina  6.502548    107.0
# 166  2015            ARM    Armenia  7.230887     63.0

# %%
## Rename Columns in temp 'Human Freedom' dataframe to allow joining/merging on ISO value for countries
# df_FreedonTemp1.rename(columns={'ISO_code':'ISO_Country_Cd'},inplace=True)

# %%
df_FreedonTemp1.head()
# Out:
#      year ISO_Country_Cd  countries  hf_score  hf_rank
# 162  2015            ALB    Albania  7.558539     49.0
# 163  2015            DZA    Algeria  5.082655    152.0
# 164  2015            AGO     Angola  5.786479    137.0
# 165  2015            ARG  Argentina  6.502548    107.0
# 166  2015            ARM    Armenia  7.230887     63.0

# %%
#del df_HpyFactor_Temp

# %%
# Augment our primary dataset on Happiness Factors per nation
# Join on the new Happiness Factors per nation datafram and only select country data from the 'Human Freedom' dataframe for 
# which we have a happiness score in the Happiness Factors dataframe
df_HpyFactor_Temp = pd.merge(df_HpyFactor_Temp, df_FreedonTemp1, how="left", on=["ISO_Country_Cd"])

# %%
df_HpyFactor_Temp.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  Trust in Gov  \
# 0  Switzerland  Western Europe               1            7.587       0.41978
# 1      Iceland  Western Europe               2            7.561       0.14145
# 2      Denmark  Western Europe               3            7.527       0.48357
# 3       Norway  Western Europe               4            7.522       0.36503
# 4       Canada   North America               5            7.427       0.32957
#
#   ISO_Country_Cd  GDP per capita  Political Fragility      Continent  \
# 0            CHE    68025.920038                 21.8         Europe
# 1            ISL    52142.932807                 22.8         Europe
# 2            DNK    52892.646029                 21.5         Europe
# 3            NOR    62987.535863                 21.2         Europe
# 4            CAN    47522.140667                 23.8  North America
#
#    hf_score_x  hf_rank_x    year    countries  hf_score_y  hf_rank_y
# 0    8.814458        3.0  2015.0  Switzerland    8.814458        3.0
# 1    8.199764       27.0  2015.0      Iceland    8.199764       27.0
# 2    8.543023        8.0  2015.0      Denmark    8.543023        8.0
# 3    8.519496       10.0  2015.0       Norway    8.519496       10.0
# 4    8.520056       10.0  2015.0       Canada    8.520056       10.0

# %%
df_HpyFactor_Temp
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 142       Rwanda               Sub-Saharan Africa             154
# 143        Benin               Sub-Saharan Africa             155
# 144        Syria  Middle East and Northern Africa             156
# 145      Burundi               Sub-Saharan Africa             157
# 146         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Trust in Gov ISO_Country_Cd  GDP per capita  \
# 0              7.587       0.41978            CHE    68025.920038
# 1              7.561       0.14145            ISL    52142.932807
# 2              7.527       0.48357            DNK    52892.646029
# 3              7.522       0.36503            NOR    62987.535863
# 4              7.427       0.32957            CAN    47522.140667
# ..               ...           ...            ...             ...
# 142            3.465       0.55191            RWA     1889.158106
# 143            3.340       0.08010            BEN     2945.970221
# 144            3.006       0.18906            SYR    11606.454800
# 145            2.905       0.10062            BDI      825.205661
# 146            2.839       0.10731            TGO     1920.469307
#
#      Political Fragility      Continent  hf_score_x  hf_rank_x    year  \
# 0                   21.8         Europe    8.814458        3.0  2015.0
# 1                   22.8         Europe    8.199764       27.0  2015.0
# 2                   21.5         Europe    8.543023        8.0  2015.0
# 3                   21.2         Europe    8.519496       10.0  2015.0
# 4                   23.8  North America    8.520056       10.0  2015.0
# ..                   ...            ...         ...        ...     ...
# 142                 91.3         Africa    7.055828       70.0  2015.0
# 143                 78.9         Africa    6.680857       94.0  2015.0
# 144                110.8           Asia    3.910826      159.0  2015.0
# 145                100.7         Africa    5.055533      153.0  2015.0
# 146                 85.8         Africa    6.195467      122.0  2015.0
#
#        countries  hf_score_y  hf_rank_y
# 0    Switzerland    8.814458        3.0
# 1        Iceland    8.199764       27.0
# 2        Denmark    8.543023        8.0
# 3         Norway    8.519496       10.0
# 4         Canada    8.520056       10.0
# ..           ...         ...        ...
# 142       Rwanda    7.055828       70.0
# 143        Benin    6.680857       94.0
# 144        Syria    3.910826      159.0
# 145      Burundi    5.055533      153.0
# 146         Togo    6.195467      122.0
#
# [147 rows x 15 columns]

# %%
# The 'countries' attribute value is useful for a quick visual inspection (above) that the mergre of dataframe has worked
# correctly but that data is now redundat and can be removed
df_HpyFactor_Temp.drop(columns=['year', 'countries'], inplace=True)

# %%
#df_HappinessFactorsbyNation = df_HpyFactor_Temp

# %%
#df_HappinessFactorsbyNation

# %%
df_tempFactorNull = df_HpyFactor_Temp[df_HpyFactor_Temp["hf_rank"].isnull()]
df_tempFactorNull
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hf_rank'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-4b5c354030de> in <module>
# ----> 1 df_tempFactorNull = df_HpyFactor_Temp[df_HpyFactor_Temp["hf_rank"].isnull()]
#       2 df_tempFactorNull
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'hf_rank'

# %% [markdown]
# Using external report data, the missing 'Human Freedom' values are added to a new temporary dataframe and used
# to update our primary 'Happiness Factors' dataframe.
#
# This information will be used for visualisations later in this assignment.

# %%
#Set up another dataframe to update missing Human Freedom Index scores
# UZB hf_score = 3.15 hf_rank = 163
# TKM hf_score = 3.14 hf_rank = 164
# DJI hf_score = 3.12 hf_rank = 165
# COM hf_score = 3.09 hf_rank = 166
# AFG hf_score = 3.05 hf_rank = 167
df_Cntry_To_Update_FreedomScr = pd.DataFrame({'ISO_Country_Cd': ['UZB','TKM','DJI','COM','AFG'],
                   'hf_score': [3.15, 3.14, 3.12, 3.09, 3.05],                  
                    'hf_rank': [163, 164, 165, 166, 167]})

# %%
df_Cntry_To_Update_FreedomScr
# Out:
#   ISO_Country_Cd  hf_score  hf_rank
# 0            UZB      3.15      163
# 1            TKM      3.14      164
# 2            DJI      3.12      165
# 3            COM      3.09      166
# 4            AFG      3.05      167

# %%
# Call function to update main dataframe with new freedom scores
update_country_dataset_wtih_new_dataframe(df_HpyFactor_Temp, df_Cntry_To_Update_FreedomScr)
# Out:
# 0:Counter in Loop - Index in Temp = Int64Index([42], dtype='int64') Country UZB
#
# 1:Counter in Loop - Index in Temp = Int64Index([66], dtype='int64') Country TKM
#
# 2:Counter in Loop - Index in Temp = Int64Index([116], dtype='int64') Country DJI
#
# 3:Counter in Loop - Index in Temp = Int64Index([129], dtype='int64') Country COM
#
# 4:Counter in Loop - Index in Temp = Int64Index([141], dtype='int64') Country AFG
# 'Here is the function'

# %%
df_HpyFactor_Temp
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 142       Rwanda               Sub-Saharan Africa             154
# 143        Benin               Sub-Saharan Africa             155
# 144        Syria  Middle East and Northern Africa             156
# 145      Burundi               Sub-Saharan Africa             157
# 146         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Trust in Gov ISO_Country_Cd  GDP per capita  \
# 0              7.587       0.41978            CHE    68025.920038
# 1              7.561       0.14145            ISL    52142.932807
# 2              7.527       0.48357            DNK    52892.646029
# 3              7.522       0.36503            NOR    62987.535863
# 4              7.427       0.32957            CAN    47522.140667
# ..               ...           ...            ...             ...
# 142            3.465       0.55191            RWA     1889.158106
# 143            3.340       0.08010            BEN     2945.970221
# 144            3.006       0.18906            SYR    11606.454800
# 145            2.905       0.10062            BDI      825.205661
# 146            2.839       0.10731            TGO     1920.469307
#
#      Political Fragility      Continent  hf_score  hf_rank
# 0                   21.8         Europe  8.814458      3.0
# 1                   22.8         Europe  8.199764     27.0
# 2                   21.5         Europe  8.543023      8.0
# 3                   21.2         Europe  8.519496     10.0
# 4                   23.8  North America  8.520056     10.0
# ..                   ...            ...       ...      ...
# 142                 91.3         Africa  7.055828     70.0
# 143                 78.9         Africa  6.680857     94.0
# 144                110.8           Asia  3.910826    159.0
# 145                100.7         Africa  5.055533    153.0
# 146                 85.8         Africa  6.195467    122.0
#
# [147 rows x 11 columns]

# %%
df_tempFactorNull = df_HpyFactor_Temp[df_HpyFactor_Temp["hf_rank"].isnull()]
df_tempFactorNull
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Trust in Gov, ISO_Country_Cd, GDP per capita, Political Fragility, Continent, hf_score, hf_rank]
# Index: []

# %%
df_HappinessFactorsbyNation = df_HpyFactor_Temp

# %%
#df_HpyFactor_Temp.drop(df_HpyFactor_Temp.iloc[:,:], axis = 1, inplace = True)

# %%
#del df_HpyFactor_Temp

# %%
#df_HpyFactor_Temp

# %% [markdown]
# ##

# %% [markdown]
# ## Run final check on structure / content of new primary datadframe for 'happiness' analysis.

# %%
## Checking for null values in new Happiness Factors dataframe
[print('Any Null Values in the new Happiness Factors dataframe?','\n' ,df_HappinessFactorsbyNation.isnull().any())]
# Out:
# Any Null Values in the new Happiness Factors dataframe?
#  Country                False
# Region                 False
# Happiness Rank         False
# Happiness Score        False
# Trust in Gov           False
# ISO_Country_Cd         False
# GDP per capita         False
# Political Fragility    False
# Continent              False
# hf_score               False
# hf_rank                False
# dtype: bool
# [None]

# %%
## Although it is an unlikely scenario - a quick check is run to see if any duplicate entires exist
[print('Numbers of duplicated rows in the Happiness Factors Dataframe?','\n' ,df_HappinessFactorsbyNation.duplicated().sum())]
# Out:
# Numbers of duplicated rows in the Happiness Factors Dataframe?
#  0
# [None]

# %% [markdown]
# #### The new Global Happiness Dataframe is now prepared and ready for visual analysis

# %%
# Check new Happiness Factors dataframe
df_HappinessFactorsbyNation
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 142       Rwanda               Sub-Saharan Africa             154
# 143        Benin               Sub-Saharan Africa             155
# 144        Syria  Middle East and Northern Africa             156
# 145      Burundi               Sub-Saharan Africa             157
# 146         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Trust in Gov ISO_Country_Cd  GDP per capita  \
# 0              7.587       0.41978            CHE    68025.920038
# 1              7.561       0.14145            ISL    52142.932807
# 2              7.527       0.48357            DNK    52892.646029
# 3              7.522       0.36503            NOR    62987.535863
# 4              7.427       0.32957            CAN    47522.140667
# ..               ...           ...            ...             ...
# 142            3.465       0.55191            RWA     1889.158106
# 143            3.340       0.08010            BEN     2945.970221
# 144            3.006       0.18906            SYR    11606.454800
# 145            2.905       0.10062            BDI      825.205661
# 146            2.839       0.10731            TGO     1920.469307
#
#      Political Fragility      Continent  hf_score  hf_rank
# 0                   21.8         Europe  8.814458      3.0
# 1                   22.8         Europe  8.199764     27.0
# 2                   21.5         Europe  8.543023      8.0
# 3                   21.2         Europe  8.519496     10.0
# 4                   23.8  North America  8.520056     10.0
# ..                   ...            ...       ...      ...
# 142                 91.3         Africa  7.055828     70.0
# 143                 78.9         Africa  6.680857     94.0
# 144                110.8           Asia  3.910826    159.0
# 145                100.7         Africa  5.055533    153.0
# 146                 85.8         Africa  6.195467    122.0
#
# [147 rows x 11 columns]

# %% [markdown]
# ##

# %% [markdown]
# #

# %% [markdown]
# ##

# %% [markdown]
# Join the CIA Country details dataframe

# %% [markdown]
# #

# %% [markdown]
# # Seaborn

# %% [markdown]
# ## Notebook Modes
# Use `matplotlib` magic to switch between `notebook` and `inline` mode.
# `tk` for new external plotting windows.

# %%
# sample array from normal distribution
x = np.random.normal(size=100)

# %%
# plot histogram with Matplotlib
_ = plt.hist(x)

# %%
# interactive figure controls
# %matplotlib notebook

# %%
sns.distplot(np.random.normal(size=100))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# default to static image
# %matplotlib inline

# %%
# plot histogram with seaborn
sns.distplot(np.random.normal(size=100), kde=False) # kde, rug
# Out:
# <AxesSubplot:>

# %%
# boxplot, violinplot
sns.violinplot(np.random.normal(size=100))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Dataset Distribution

# %%
# load iris dataset
# iris_df = sns.load_dataset('iris')
# iris_df.head()

# %%
# exaple pairplot for iris dataset
# notice we define what column to use for hue variations 
# sns.pairplot(iris_df, hue='species')

# %% [markdown]
# ## Categorical Data

# %%
# load titanic dataset
#titanic_df = sns.load_dataset('titanic')
#titanic_df.head()

# %%
# exaple factorplot/catplot for titanic dataset
# sns.catplot(data=titanic_df, x='alive', col='deck', row='sex', 
#            kind='count')

# %%
# exaple factorplot/catplot for titanic dataset (bar, violin, swarm, box)
# sns.catplot(data=titanic_df, y='age', col='deck', kind='bar')

# %% [markdown]
# ## Time-Series Data

# %%
# create dummy time-series dataframe
df = pd.DataFrame(dict(time=pd.date_range("2017-1-1", periods=500),
                       value=np.random.randn(500).cumsum()))
# plot with seaborn
g = sns.relplot(x="time", y="value", kind="line", data=df)
g.fig.autofmt_xdate()

# %% [markdown]
# # Pandas Plotting

# %%
# direct plot from Pandas df
# iris_df.plot()

# %%
# compute and plot average attribute value for each species
# iris_df.groupby('species').agg(np.mean).plot(kind='bar')

# %% [markdown]
# # Plotly

# %%
# install plotly and cufflinks in current virtual-env

# %%
#pip install plotly
#pip install cufflinks

# %%
# Import libraries and set offline mode
#from plotly.offline import init_notebook_mode, plot, iplot
#import cufflinks as cf
#init_notebook_mode(connected=True)
#cf.go_offline(connected=True)
#enable_mpl_offline()

# %%
# Plot data via plotly
#import plotly.graph_objs as go

#data = [go.Histogram(x=x)]
#iplot(data)

# %%
# plot Pandas data via plotly
#iris_df.iplot()

# %%
# Export cufflink plot
#fig = iris_df.iplot(asFigure=True)
#plot(fig, filename="iris.html")

# %% [markdown]
# ## Transfer Matplotlib Figure to Plotly

# %%
#import plotly.tools as tls

# create figure and plot in matplot
#mpl_fig = plt.figure()
#ax = mpl_fig.add_subplot(111)
#ax.hist(np.random.normal(size=100))

# convert and plot in plotly
#plotly_fig = tls.mpl_to_plotly(ax.figure)
#iplot(plotly_fig)

# %% [markdown]
# # Animation

# %%
from matplotlib import animation

# %matplotlib notebook

fig, ax = plt.subplots(dpi=100, figsize=(5, 4))
ax.set_xlim(0, 2)
ax.set_ylim(-2, 2)

line, = ax.plot([], [], lw=2)
#epoch_text = ax.text(0, 0, "Epoch 0")

def animate(i, line):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    #epoch_text.set_text("Epoch {}".format(i, cost))
    line.set_data(x, y)
    return line

ani = animation.FuncAnimation(fig, animate, 100, interval=10, repeat=True,
                             fargs=[line])
# Out:
# <img src="data:image/png;base64,..." width="499.9999801317859">

# %% [markdown]
# ##

# %% [markdown]
# # Part 2
#
# ## Carry out exploration of this dataframe to develop an overall understanding of the data.

# %% [markdown]
# ##

# %%
# default to static image
# %matplotlib inline

# %%
df_count = df_HappinessFactorsbyNation[df_HappinessFactorsbyNation['Region'] == 'Western Europe']
df_count
# Out:
#            Country          Region  Happiness Rank  Happiness Score  \
# 0      Switzerland  Western Europe               1            7.587
# 1          Iceland  Western Europe               2            7.561
# 2          Denmark  Western Europe               3            7.527
# 3           Norway  Western Europe               4            7.522
# 5          Finland  Western Europe               6            7.406
# 6      Netherlands  Western Europe               7            7.378
# 7           Sweden  Western Europe               8            7.364
# 12         Austria  Western Europe              13            7.200
# 16      Luxembourg  Western Europe              17            6.946
# 17         Ireland  Western Europe              18            6.940
# 18         Belgium  Western Europe              19            6.937
# 20  United Kingdom  Western Europe              21            6.867
# 25         Germany  Western Europe              26            6.750
# 28          France  Western Europe              29            6.575
# 34           Spain  Western Europe              36            6.329
# 35           Malta  Western Europe              37            6.302
# 48           Italy  Western Europe              50            5.948
# 64          Cyprus  Western Europe              67            5.689
# 83        Portugal  Western Europe              88            5.102
# 94          Greece  Western Europe             102            4.857
#
#     Trust in Gov ISO_Country_Cd  GDP per capita  Political Fragility  \
# 0        0.41978            CHE    68025.920038                 21.8
# 1        0.14145            ISL    52142.932807                 22.8
# 2        0.48357            DNK    52892.646029                 21.5
# 3        0.36503            NOR    62987.535863                 21.2
# 5        0.41372            FIN    45072.590215                 18.8
# 6        0.31814            NLD    52974.116220                 28.2
# 7        0.43844            SWE    50928.962976                 22.6
# 12       0.18676            AUT    52798.099461                 27.5
# 16       0.37798            LUX   110446.086102                 24.1
# 17       0.28703            IRL    72251.153536                 22.5
# 18       0.22540            BEL    49455.441337                 29.0
# 20       0.32067            GBR    44840.782644                 32.4
# 25       0.21843            DEU    51083.921662                 28.6
# 28       0.20646            FRA    43345.786428                 34.5
# 34       0.06398            ESP    37377.068017                 39.8
# 35       0.13586            MLT    39845.114567                 39.6
# 48       0.02901            ITA    40247.829044                 43.1
# 64       0.06146            CYP    34472.298507                 64.0
# 83       0.01078            PRT    31118.790670                 29.2
# 94       0.01397            GRC    28248.125956                 55.9
#
#    Continent  hf_score  hf_rank
# 0     Europe  8.814458      3.0
# 1     Europe  8.199764     27.0
# 2     Europe  8.543023      8.0
# 3     Europe  8.519496     10.0
# 5     Europe  8.558935      6.0
# 6     Europe  8.548259      7.0
# 7     Europe  8.484574     13.0
# 12    Europe  8.509897     12.0
# 16    Europe  8.484667     13.0
# 17    Europe  8.645525      4.0
# 18    Europe  8.307857     21.0
# 20    Europe  8.528704      9.0
# 25    Europe  8.480457     13.0
# 28    Europe  8.004391     35.0
# 34    Europe  8.175966     28.0
# 35    Europe  8.380704     18.0
# 48    Europe  8.013608     34.0
# 64    Europe  8.179577     28.0
# 83    Europe  8.295668     22.0
# 94    Europe  7.260917     58.0

# %%
df_count.shape
# Out:
# (20, 11)

# %%
df_count = df_HappinessFactorsbyNation[df_HappinessFactorsbyNation['Region'] == 'Sub-Saharan Africa']
df_count
# Out:
#                       Country              Region  Happiness Rank  \
# 67                  Mauritius  Sub-Saharan Africa              71
# 73                    Nigeria  Sub-Saharan Africa              78
# 80                     Zambia  Sub-Saharan Africa              85
# 87                 Mozambique  Sub-Saharan Africa              94
# 90                    Lesotho  Sub-Saharan Africa              97
# 104              South Africa  Sub-Saharan Africa             113
# 105                     Ghana  Sub-Saharan Africa             114
# 106                  Zimbabwe  Sub-Saharan Africa             115
# 107                   Liberia  Sub-Saharan Africa             116
# 109                     Sudan  Sub-Saharan Africa             118
# 112                  Ethiopia  Sub-Saharan Africa             122
# 113              Sierra Leone  Sub-Saharan Africa             123
# 114                Mauritania  Sub-Saharan Africa             124
# 115                     Kenya  Sub-Saharan Africa             125
# 116                  Djibouti  Sub-Saharan Africa             126
# 118                  Botswana  Sub-Saharan Africa             128
# 121                    Malawi  Sub-Saharan Africa             131
# 123                  Cameroon  Sub-Saharan Africa             133
# 127                    Angola  Sub-Saharan Africa             137
# 128                      Mali  Sub-Saharan Africa             138
# 129                   Comoros  Sub-Saharan Africa             140
# 130                    Uganda  Sub-Saharan Africa             141
# 131                   Senegal  Sub-Saharan Africa             142
# 132                     Gabon  Sub-Saharan Africa             143
# 133                     Niger  Sub-Saharan Africa             144
# 135                  Tanzania  Sub-Saharan Africa             146
# 136                Madagascar  Sub-Saharan Africa             147
# 137  Central African Republic  Sub-Saharan Africa             148
# 138                      Chad  Sub-Saharan Africa             149
# 139                    Guinea  Sub-Saharan Africa             150
# 140              Burkina Faso  Sub-Saharan Africa             152
# 142                    Rwanda  Sub-Saharan Africa             154
# 143                     Benin  Sub-Saharan Africa             155
# 145                   Burundi  Sub-Saharan Africa             157
# 146                      Togo  Sub-Saharan Africa             158
#
#      Happiness Score  Trust in Gov ISO_Country_Cd  GDP per capita  \
# 67             5.477       0.07521            MUS    19897.475397
# 73             5.268       0.04030            NGA     5514.770273
# 80             5.129       0.12468            ZMB     3443.553254
# 87             4.971       0.15603            MOZ     1262.613128
# 90             4.898       0.12504            LSO     2701.421855
# 104            4.642       0.08884            ZAF    12840.035403
# 105            4.633       0.04355            GHA     4662.303191
# 106            4.610       0.08079            ZWE     3198.982129
# 107            4.571       0.06232            LBR     1580.479228
# 109            4.550       0.14660            SDN     4187.862722
# 112            4.512       0.15048            ETH     1779.084111
# 113            4.507       0.08786            SLE     1551.823091
# 114            4.436       0.17461            MRT     5127.432282
# 115            4.419       0.05839            KEN     3824.759303
# 116            4.369       0.28105            DJI     4488.802658
# 118            4.332       0.12474            BWA    16714.397822
# 121            4.292       0.06977            MWI     1432.085259
# 123            4.252       0.05786            CMR     3458.692713
# 127            4.033       0.07122            AGO     8036.410898
# 128            3.995       0.12352            MLI     2139.736297
# 129            3.956       0.19900            COM     2959.498097
# 130            3.931       0.07267            UGA     2054.090449
# 131            3.904       0.10713            SEN     2966.455347
# 132            3.896       0.11091            GAB    15510.038951
# 133            3.845       0.15639            NER     1132.331205
# 135            3.781       0.05747            TZA     2354.138985
# 136            3.681       0.08124            MDG     1546.767046
# 137            3.678       0.08289            CAF      852.749237
# 138            3.667       0.05269            TCD     1857.107864
# 139            3.656       0.12139            GIN     2087.935026
# 140            3.587       0.12832            BFA     1925.332075
# 142            3.465       0.55191            RWA     1889.158106
# 143            3.340       0.08010            BEN     2945.970221
# 145            2.905       0.10062            BDI      825.205661
# 146            2.839       0.10731            TGO     1920.469307
#
#      Political Fragility Continent  hf_score  hf_rank
# 67                  43.2    Africa  7.900516     38.0
# 73                 103.5    Africa  6.010441    130.0
# 80                  86.3    Africa  6.434490    113.0
# 87                  87.8    Africa  6.204761    122.0
# 90                  80.9    Africa  6.585666    101.0
# 104                 69.9    Africa  7.256592     58.0
# 105                 71.2    Africa  7.115640     67.0
# 106                100.5    Africa  5.582640    142.0
# 107                 95.5    Africa  6.620195     98.0
# 109                111.5    Africa  3.320000    162.0
# 112                 97.2    Africa  5.353159    148.0
# 113                 91.0    Africa  6.478120    109.0
# 114                 95.4    Africa  5.370913    147.0
# 115                 98.3    Africa  6.716695     89.0
# 116                 89.7    Africa  3.120000    165.0
# 118                 63.5    Africa  7.070066     69.0
# 121                 87.6    Africa  6.608429     99.0
# 123                 97.8    Africa  5.458970    144.0
# 127                 90.5    Africa  5.786479    137.0
# 128                 95.2    Africa  5.895995    132.0
# 129                 83.8    Africa  3.090000    166.0
# 130                 97.7    Africa  6.709795     90.0
# 131                 83.6    Africa  6.496134    107.0
# 132                 72.0    Africa  5.549343    143.0
# 133                 98.4    Africa  5.672235    139.0
# 135                 81.8    Africa  6.555737    102.0
# 136                 84.2    Africa  6.597625    100.0
# 137                112.1    Africa  5.124578    151.0
# 138                110.1    Africa  5.432498    146.0
# 139                103.8    Africa  5.650031    140.0
# 140                 89.4    Africa  6.698858     92.0
# 142                 91.3    Africa  7.055828     70.0
# 143                 78.9    Africa  6.680857     94.0
# 145                100.7    Africa  5.055533    153.0
# 146                 85.8    Africa  6.195467    122.0

# %%
df_count.shape
# Out:
# (35, 11)

# %% [markdown]
# #### Present the number of countries in out reworked dataframe based on their global regions

# %%
# Group the count of countries by region and present in a bar chart

df_HappinessFactorsbyNation.groupby('Region').size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Region'>

# %% [markdown]
# ##

# %% [markdown]
# # Part 3
#
# ## Focus on a particular subset of the dataframe and drill down into it extracting details to answer a series of questions that are of interest to you as an analyst - Ideally the motivation for such questions would be framed within the context of a hypothetical use case scenario

# %% [markdown]
# #

# %% [markdown]
# ### Using our new dataframe, start with an analysis of how 'happiness; is impacted by GDP and Political Fragility

# %%
## Set up a scatter plot and line diagram to correlate 'happiness' with a nations GDP and political stability
fig, (ax1, ax2) = plt.subplots(figsize = (17,6), ncols=2, sharey=False)


## First compare GDP to the Kaggle 'Happiness Index'
sns.scatterplot(x=df_HappinessFactorsbyNation['GDP per capita'],
                y=df_HappinessFactorsbyNation['Happiness Score'],
                color='#ff4d6d',ax=ax1)

sns.regplot(x=df_HappinessFactorsbyNation['GDP per capita'],
            y=df_HappinessFactorsbyNation['Happiness Score'],
            ax=ax1,color='#ff4d6d')


## Then compare GDP to the Kaggle 'Happiness Index'
sns.scatterplot(x=df_HappinessFactorsbyNation['Political Fragility'],
                y=df_HappinessFactorsbyNation['Happiness Score'],
                ax=ax2,color='#90be6d')

sns.regplot(x=df_HappinessFactorsbyNation['Political Fragility'],
            y=df_HappinessFactorsbyNation['Happiness Score'],
            ax=ax2,color='#90be6d')
# Out:
# <AxesSubplot:xlabel='Political Fragility', ylabel='Happiness Score'>

# %% [markdown]
# #### Although nations with a greater GDP are generally 'happier', there is a noticable pattern that after approximatelt 65K further increases in GDP do not make a increase the Happiness Core for a country.

# %% [markdown]
# #### However, as the political instability of a country increases (the Political Fragility index grows larger) there is a relatively impact on a nations 'happiness' - although there are some outliers.

# %% [markdown]
# # Jupyter Magic

# %%
# %%html
# <h1>Table</h1>
# <table style="width:100%">
#   <tr>
#     <th>Firstname</th>
#     <th>Lastname</th>
#     <th>Age</th>
#   </tr>
#   <tr>
#     <td>Jill</td>
#     <td>Smith</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>Eve</td>
#     <td>Jackson</td>
#     <td>94</td>
#   </tr>
# </table>
# Out:
# <h1>Table</h1>
# <table style="width:100%">
#   <tr>
#     <th>Firstname</th>
#     <th>Lastname</th>
#     <th>Age</th>
#   </tr>
#   <tr>
#     <td>Jill</td>
#     <td>Smith</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>Eve</td>
#     <td>Jackson</td>
#     <td>94</td>
#   </tr>
# </table>
